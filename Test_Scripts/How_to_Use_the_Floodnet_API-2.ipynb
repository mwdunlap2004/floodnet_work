# %% [markdown]
# # Floodnet API Access using Python
# > I've updated the API examples to utilize REST API endpoints.
#
# This notebook will show you how to accomplish:
#  - Querying all deployed Floodnet sensors
#  - Querying sensors near a specific location
#  - Querying the data for sensors within a specific time range

# %% [markdown]
# ## Setup

# %%
# they are likely already installed
# !pip install requests folium humanize pandas

# %%
# for making API requests
import requests
# showing Maps
import folium
import folium.plugins
# standard data processing and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(15, 4))

# %% [markdown]
# ## Where are the sensors located?
#
# The places where sensors are mounted are referred to as *Deployments*. Each deployment represents a single sensor mounted in a single location.
#
# The returned fields are:
#  - **`name`**: The name of the sensor.
#  - **`location`**: A [GeoJSON](https://geojson.org/) geometry representation of the sensor location. The `crs` key defines the map projection. We return the commonly used WGS84 projection.
#  - **`deployment_id`**: The unique ID representing the sensor. **You can use this as the ID to query data for a specific sensor.**
#  - **`date_deployed`**: The date that the sensor was deployed.
#  - **`date_down`**: The date that the sensor was taken down (if at all).
#  - **`deploy_type`**: The type of a sensor:
#     - pluvial: The sensor is primarily driven by pluvial/rainstorm flooding
#     - coastal: The sensor is primarily driven by coastal/tidal flooding

# %% [markdown]
# ### Querying the data
# We're going to:
#  - request the data from the API
#  - load it using [Pandas](https://pandas.pydata.org/docs/index.html) (a tabular data library)

# %%
def get_deployments():
    '''Retrieve a table of all sensor deployment locations.

    '''
    # query the API
    deployments = requests.get("https://api.floodnet.nyc/api/rest/deployments/flood").json()
    if 'error' in deployments:
        raise RuntimeError(str(deployments))

    # create a pandas table
    df = pd.DataFrame(deployments['deployments'])

    # drop any sensors without a location (TODO: do this within the query)
    df = df.dropna(subset=['location'])

    # convert date strings to datetime objects
    df['date_deployed'] = pd.to_datetime(df.date_deployed).dt.tz_localize(tz='America/New_York')
    df['date_down'] = pd.to_datetime(df.date_down).dt.tz_localize(tz='America/New_York')

    # extract latitude, longitude pair
    df['coordinates'] = [np.array(x['coordinates'][::-1]) for x in df.location]
    return df

# %%
# get a dataframe of flood deployments
df_deployments = get_deployments()

# show a summary
print(len(df_deployments), "results")
df_deployments.head()
# Out:
# 112 results
#                        name          deployment_id             date_deployed  \
# 0       Q - 1st St/104th St      big_pink_elephant 2023-03-17 00:00:00-04:00
# 1    Q - 159th St/109th Ave  boring_olive_stingray 2022-06-10 00:00:00-04:00
# 2  BK - Walton St/Marcy Ave   clearly_bored_turtle 2023-03-09 00:00:00-05:00
# 3      Q - 30th Ave/89th St   closely_muddy_scurvy 2024-01-12 00:00:00-05:00
# 4           Q - Beach 84 St      daily_happy_satyr 2021-12-10 00:00:00-05:00
#
#   date_down deploy_type                                           location  \
# 0       NaT     coastal  {'type': 'Point', 'crs': {'type': 'name', 'pro...
# 1       NaT     pluvial  {'type': 'Point', 'crs': {'type': 'name', 'pro...
# 2       NaT     pluvial  {'type': 'Point', 'crs': {'type': 'name', 'pro...
# 3       NaT     pluvial  {'type': 'Point', 'crs': {'type': 'name', 'pro...
# 4       NaT     coastal  {'type': 'Point', 'crs': {'type': 'name', 'pro...
#
#   image      sensor_mount mounted_over sensor_status  \
# 0  None  streetsign post      sidewalk            up
# 1  None   streetsign post     sidewalk       retired
# 2  None   streetsign post     sidewalk            up
# 3  None   streetsign post     sidewalk            up
# 4  None             fence     sidewalk            up
#
#                    coordinates
# 0     [40.6559075, -73.828642]
# 1  [40.69395022, -73.79308702]
# 2  [40.70082053, -73.95133488]
# 3  [40.76183408, -73.87997808]
# 4        [40.59136, -73.80996]

# %% [markdown]
# ### Visualizing the data
#  - draw markers on a map using a mapping library called [Folium](https://python-visualization.github.io/folium/latest/)
#  - use different styles to differentiate sensors
#     - retired sensors (sensors that are no longer up) will be drawn in red
#     - pluvial sensors will be drawn in dark blue with a rain icon
#     - coastal sensors will be drawn in light blue with a wave icon

# %%
def draw_markers(map, df):
    '''Draw sensor markers on a map.
    '''
    # Add markers for each deployment location
    for _, row in df.iterrows():
        # show different icon styles based on sensor data
        icon_kw = {}
        if row.deploy_type == 'coastal':
            icon_kw.update(dict(color='blue', icon='water'))
        else:
            icon_kw.update(dict(color='darkblue', icon='cloud-rain'))
        if not pd.isna(row.date_down):
            icon_kw['color'] = 'red'

        # draw marker
        folium.Marker(
            row.coordinates,
            icon=folium.Icon(prefix='fa', **icon_kw),
            tooltip=f"<b>{row['name']}</b>",
            popup=folium.Popup(
                f"<b style=\"font-size: 1.3em\">{row['name']}</b><br>"
                f"<b>Deploy Type</b>: {row.deploy_type}<br>"
                f"<b>Date Deployed</b>: {row.date_deployed.strftime('%b %d, %Y')}<br>"
                f"<b>Date Down</b>: {row.date_down.strftime('%b %d, %Y') if not pd.isna(row.date_down) else '--'}<br>"
                f"<b>Location</b>: {row.coordinates.tolist()}<br>"
            , max_width=200)
        ).add_to(map)

# %%
# get the center of the map using the average of sensor coordinates
map_center = df_deployments.coordinates.dropna().mean(0)

# let's create the map
map = folium.Map(location=map_center, zoom_start=11, tiles="CartoDB Positron", attr="CartoDB")
folium.plugins.ScrollZoomToggler().add_to(map)  # disables scroll-zoom by default

# draw the markers
draw_markers(map, df_deployments)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41148796668fd5fc5a6568b1ebef676d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_42d0bd7121f641f65f53d0212faaf363 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41148796668fd5fc5a6568b1ebef676d&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_42d0bd7121f641f65f53d0212faaf363&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_41148796668fd5fc5a6568b1ebef676d.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41148796668fd5fc5a6568b1ebef676d = L.map(
#                 &quot;map_41148796668fd5fc5a6568b1ebef676d&quot;,
#                 {
#                     center: [40.68987756428571, -73.91078342892855],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab0047efe8ed6ef88bfacd9be20c2961 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_41148796668fd5fc5a6568b1ebef676d);
#
#
#             map_41148796668fd5fc5a6568b1ebef676d.scrollEnabled = true;
#
#             map_41148796668fd5fc5a6568b1ebef676d.toggleScroll = function() {
#                 if (this.scrollEnabled) {
#                     this.scrollEnabled = false;
#                     this.scrollWheelZoom.disable();
#                 } else {
#                     this.scrollEnabled = true;
#                     this.scrollWheelZoom.enable();
#                 }
#             };
#             map_41148796668fd5fc5a6568b1ebef676d.toggleScroll();
#
#
#             var marker_59c3b630c43c1f0991388bbc4a2a6f32 = L.marker(
#                 [40.6559075, -73.828642],
#                 {}
#             ).addTo(map_41148796668fd5fc5a6568b1ebef676d);
#
#
#             var icon_bfc163f212d9ca47e65f2afef8bbf261 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;water&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_59c3b630c43c1f0991388bbc4a2a6f32.setIcon(icon_bfc163f212d9ca47e65f2afef8bbf261);
#
#
#         var popup_4309f51dc1c23e6f9044dc0544b0223b = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_15ebcd37ad80dd1d12a9e63ab551f28a = $(`&lt;div id=&quot;html_15ebcd37ad80dd1d12a9e63ab551f28a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b style=&quot;font-size: 1.3em&quot;&gt;Q - 1st St/104th St&lt;/b&gt;&lt;br&gt;&lt;b&gt;Deploy Type&lt;/b&gt;: coastal&lt;br&gt;&lt;b&gt;Date Deployed&lt;/b&gt;: Mar 17, 2023&lt;br&gt;&lt;b&gt;Date Down&lt;/b&gt;: --&lt;br&gt;&lt;b&gt;Location&lt;/b&gt;: [40.6559075, -73.828642]&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_4309f51dc1c23e6f9044dc0544b0223b.setContent(html_15ebcd37ad80dd1d12a9e63ab551f28a);
#
#
#
#         marker_59c3b630c43c1f0991388bbc4a2a6f32.bindPopup(popup_4309f51dc1c23e6f9044dc0544b0223b)
#         ;
#
#
#
#
#             marker_59c3b630c43c1f0991388bbc4a2a6f32.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Q - 1st St/104th St&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f50aec871b82879eeedc9d7d35f734c1 = L.marker(
#                 [40.69395022, -73.79308702],
#                 {}
#             ).addTo(map_41148796668fd5fc5a6568b1ebef676d);
#
#
#             var icon_d3241f6179b2b0114b09348a5d0eba8c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud-rain&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f50aec871b82879eeedc9d7d35f734c1.setIcon(icon_d3241f6179b2b0114b09348a5d0eba8c);
#
#
#         var popup_a9b1ab74e118a15128edd318dcae395e =

# %% [markdown]
# ## Can we search in a specific area?
#
# You can also do geographical queries like this! Just specify a latitude, longitude, and search radius in units of meters.
#
# If you need help getting your location, you can try:
#  - [Address reverse geocode](https://www.latlong.net/)
#  - Google Maps
#     - Find your current location on the map
#     - Click on blank space near your location (anywhere without a specific address)
#     - this should show a little box at the bottom of the screen with two numbers in blue:
#         - latitude (a number around 40 to 41)
#         - longitude (a number around -73 to -74)
#  - Use the coordinates of an existing sensor (see map above)

# %% [markdown]
# ### Querying the data
# Let's search around the Gowanus Canal.
#
# We're going to:
#  - request the data from the API using query parameters to specify where we want to search.
#  - load the data using Pandas
#
#  > The API limits the response to 3000 rows. This equates to around 2 days of data (assuming upload rate of 1 message per minute).

# %%
def search_deployments(lat, lon, radius_meters):
    '''Search for deployments around a specific latitude and longitude.

    '''
    # query the API
    deployments = requests.get("https://api.floodnet.nyc/api/rest/deployments/flood/near", params={
        'lat': lat, 'lon': lon, 'radius_meters': radius_meters,
    }).json()
    if 'error' in deployments:
        raise RuntimeError(str(deployments))

    # lets create a pandas dataframe
    df = pd.DataFrame(deployments['deployments_within_radius'])
    # drop any sensors without a location (TODO: do this within the query)
    df = df.dropna(subset=['location'])
    # convert date strings to datetime objects
    df['date_deployed'] = pd.to_datetime(df.date_deployed, format='ISO8601').dt.tz_localize(tz='America/New_York')
    df['date_down'] = pd.to_datetime(df.date_down, format='ISO8601').dt.tz_localize(tz='America/New_York')
    # extract latitude, longitude pair
    df['coordinates'] = [np.array(x['coordinates'][::-1]) for x in df.location]
    return df

# %%
# QUERY PARAMETERS: the latitude/longitude pair, and the search radius
lat_lon_query = [40.67517255, -73.99058232]
radius = 750  # meters

# query the API
df_search = search_deployments(lat_lon_query[0], lat_lon_query[1], radius)

# show a summary
print(len(df_search), "results")
df_search.head()
# Out:
# 5 results
#                       name         deployment_id             date_deployed  \
# 0      BK - Hoyt St/5th St      daily_new_falcon 2020-10-05 00:00:00-04:00
# 1  BK - 4th Av/Garfield Pl   daily_gentle_beetle 2021-07-15 00:00:00-04:00
# 2     BK - 9th St/Smith St   overly_heroic_squid 2021-12-14 00:00:00-05:00
# 3   BK - Carroll St/4th Av  weekly_poetic_guinea 2021-07-15 00:00:00-04:00
# 4     BK - 9th St/Smith St   widely_proud_lizard 2021-07-16 00:00:00-04:00
#
#                   date_down deploy_type  \
# 0                       NaT     pluvial
# 1                       NaT     pluvial
# 2                       NaT     pluvial
# 3                       NaT     pluvial
# 4 2021-12-10 00:00:00-05:00     pluvial
#
#                                             location image     sensor_mount  \
# 0  {'type': 'Point', 'crs': {'type': 'name', 'pro...  None  streetsign post
# 1  {'type': 'Point', 'crs': {'type': 'name', 'pro...  None  streetsign post
# 2  {'type': 'Point', 'crs': {'type': 'name', 'pro...  None  streetsign post
# 3  {'type': 'Point', 'crs': {'type': 'name', 'pro...  None  streetsign post
# 4  {'type': 'Point', 'crs': {'type': 'name', 'pro...  None  streetsign post
#
#   mounted_over sensor_status                  coordinates
# 0     sidewalk            up  [40.67667202, -73.99459095]
# 1     sidewalk            up  [40.67585478, -73.98394371]
# 2     sidewalk            up      [40.673401, -73.994892]
# 3     sidewalk            up  [40.67628059, -73.98408855]
# 4     sidewalk       retired  [40.67365435, -73.99539641]

# %% [markdown]
# ### Visualizing the data
#  - draw the search radius on the map
#  - draw markers on the map

# %%
# get the center of the map using the average of sensor coordinates
map_center = df_search.coordinates.dropna().mean(0)

# let's create the map
map = folium.Map(location=map_center, zoom_start=15, tiles="CartoDB Positron", attr="CartoDB")
folium.plugins.ScrollZoomToggler().add_to(map)  # disables scroll-zoom by default

# let's display our search radius so we can see where our sensors lie within it
folium.Circle(
    location=lat_lon_query,
    radius=radius,
    fill_opacity=0.4,
    fill_color="lightblue",
    tooltip=f"I'm the {radius} meter radius",
).add_to(map)
folium.CircleMarker(
    location=lat_lon_query,
    radius=7,
    fill_color='black',
    fill_opacity=0.6,
    tooltip=f"I'm the point you queried.",
).add_to(map)

# draw deployment locations
draw_markers(map, df_search)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21320da25959533359acc375a6027353 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_ec97475731f75ed8ba2dc2d6df9b5399 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21320da25959533359acc375a6027353&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_ec97475731f75ed8ba2dc2d6df9b5399&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_21320da25959533359acc375a6027353.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21320da25959533359acc375a6027353 = L.map(
#                 &quot;map_21320da25959533359acc375a6027353&quot;,
#                 {
#                     center: [40.67517254799999, -73.990582324],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afc59e31c50ca3fc4e24b251ca7d0628 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_21320da25959533359acc375a6027353);
#
#
#             map_21320da25959533359acc375a6027353.scrollEnabled = true;
#
#             map_21320da25959533359acc375a6027353.toggleScroll = function() {
#                 if (this.scrollEnabled) {
#                     this.scrollEnabled = false;
#                     this.scrollWheelZoom.disable();
#                 } else {
#                     this.scrollEnabled = true;
#                     this.scrollWheelZoom.enable();
#                 }
#             };
#             map_21320da25959533359acc375a6027353.toggleScroll();
#
#
#             var circle_d351ecf420e8a30d3d87b8145afcc2ab = L.circle(
#                 [40.67517255, -73.99058232],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 750, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_21320da25959533359acc375a6027353);
#
#
#             circle_d351ecf420e8a30d3d87b8145afcc2ab.bindTooltip(
#                 `&lt;div&gt;
#                      I&#x27;m the 750 meter radius
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_91efcff55e032a53128726b4da7966bd = L.circleMarker(
#                 [40.67517255, -73.99058232],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_21320da25959533359acc375a6027353);
#
#
#             circle_marker_91efcff55e032a53128726b4da7966bd.bindTooltip(
#                 `&lt;div&gt;
#                      I&#x27;m the point you queried.
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9964a7980cf0769759dddb659e321794 = L.marker(
#                 [40.67585478, -73.98394371],
#                 {}
#             ).addTo(map_21320da25959533359acc375a6027353);
#
#
#             var icon_8dacedb2fe865492d96b482423349510 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud-rain&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9964a7980cf0769759dddb659e321794.setIcon(icon_8dacedb2fe86549

# %% [markdown]
# ## Can we get the data for those sensors at a specific time?
#
# Yes! For example, let's query their data during Hurricane Ida.

# %% [markdown]
# ### Function Definitions

# %%
# create a lookup table for deployment_id -> sensor name
# TODO: add this field to the API response
sensor_name_lookup = df_deployments.set_index('deployment_id').name

# %%
def query_depth_data(deployment_id, start_time, end_time):
    data = requests.get(f"https://api.floodnet.nyc/api/rest/deployments/flood/{deployment_id}/depth", params={
        'start_time': start_time,
        'end_time': end_time,
    }).json()
    if 'error' in data:
        raise RuntimeError(data)
    print(data)
    # lets create a pandas dataframe
    df_depth = pd.DataFrame(data['depth_data'], columns=['deployment_id', 'time', 'depth_proc_mm'])

    # drop missing depth values
    df_depth = df_depth.dropna(subset=['depth_proc_mm'])

    # add the sensor name to the table
    df_depth['name'] = df_depth.deployment_id.apply(lambda name: sensor_name_lookup.get(name))

    # convert the time string to a datetime object
    df_depth['time'] = pd.to_datetime(df_depth['time'], format='ISO8601')

    # convert millimeters to inches
    df_depth['depth_inches'] = df_depth['depth_proc_mm'] / 25.4

    # use time as the dataframe index
    df_depth = df_depth.set_index('time')
    return df_depth

def query_depth_data_for_multiple_deployments(df, start_time, end_time):
    # filter out sensors that were not online during the event
    df_active = df
    #  [
    #     (df.date_deployed < pd.to_datetime(start_time))
    # ]

    # query depth data for all sensors
    df_depth = pd.concat([
        query_depth_data(deployment_id, start_time, end_time)
        for deployment_id in df_active.deployment_id
    ])

    return df_depth

# %%
def draw_depth_data(df_depth, title):
    df_depth.groupby('name').depth_inches.plot()
    plt.legend()
    plt.title(title)
    plt.ylabel("Depth (inches)")

# %% [markdown]
# ### Hurricane Ida

# %%
# query depth data for all sensors
df_depth = query_depth_data_for_multiple_deployments(
    df_search,
    start_time="2021-09-01T14:00:00-04:00",
    end_time="2021-09-02T06:00:00-04:00",
)

# show a summary
print(len(df_depth), "results")
df_depth.head()
# Out:
# {'depth_data': []}
# {'depth_data': [{'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:01:53.767764+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:06:01.215691+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:10:08.657105+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:14:16.044238+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:18:23.449224+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:22:30.780695+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:26:38.043015+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:30:45.10127+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:34:52.07147+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:38:59.060816+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:43:06.202614+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:47:13.249873+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:51:20.249655+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:55:27.428294+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T18:59:34.654649+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:03:41.910189+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:07:49.174211+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:11:56.481794+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:16:03.812269+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:20:11.170344+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:24:18.468814+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:28:25.729315+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:32:33.036566+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:36:40.377997+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:40:47.828567+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:44:55.34609+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:49:02.920212+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:53:10.520558+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T19:57:18.139001+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T20:01:25.752064+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T20:05:33.325319+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T20:09:40.907103+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T20:13:48.508866+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T20:17:56.164051+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T20:22:03.86141+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T20:26:11.573688+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T20:30:19.30198+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T20:34:27.070024+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2021-09-01T20:38:34.849623+0 ...
# {'depth_data': []}
# {'depth_data': [{'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T18:00:42.392316+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T18:05:53.194+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T18:11:03.981692+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T18:16:14.738334+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T18:21:25.500435+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T18:31:46.791511+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T18:36:57.38373+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T18:42:07.868453+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T18:47:18.393794+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T18:52:28.970957+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T18:57:39.575979+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:02:50.201431+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:08:00.809987+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:13:11.445641+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:18:22.089428+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:23:32.757183+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:28:43.415123+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:33:54.207241+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:39:04.884646+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:44:15.812077+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:49:26.621534+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:54:37.528334+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T19:59:48.46055+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T20:04:59.283345+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T20:10:10.285045+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T20:15:21.207523+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T20:20:32.034652+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T20:25:43.010302+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T20:30:54.008005+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T20:36:04.994741+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T20:41:15.992589+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T20:46:26.994697+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T20:51:38.006328+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T20:56:49.066444+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T21:02:00.170084+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T21:07:11.264105+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2021-09-01T21:12:22.470723+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poet ...
# {'depth_data': [{'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T18:04:13.693092+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T18:09:23.402797+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T18:14:33.126104+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T18:19:42.907785+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T18:30:01.905428+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T18:35:11.209238+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T18:40:20.279389+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T18:45:29.661889+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T18:50:39.000832+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T18:55:48.450969+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T19:00:57.994709+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T19:06:07.653236+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T19:11:17.318165+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T19:16:26.962855+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T19:21:36.604522+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T19:26:46.202175+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T19:31:55.749231+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T19:42:15.288033+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T19:47:25.080411+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T19:52:35.106971+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T19:57:44.990073+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:02:54.888218+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:08:04.763611+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:13:14.670907+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:18:24.616204+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:23:34.641361+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:28:44.674836+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:33:54.766168+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:39:04.877482+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:44:15.009201+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:49:25.163989+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:54:35.361448+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01T20:59:45.589449+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'widely_proud_lizard', 'time': '2021-09-01
deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:00:40.857+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:01:44.15+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:02:47.495+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:03:50.399+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:04:53.777+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:05:56.804+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:06:59.404+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:08:02.84+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:09:05.834+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:10:08.435+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:11:11.635+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:12:14.688+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:13:17.974+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:14:21.145+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:15:24.151+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:16:26.708+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:17:29.547+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:18:32.912+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:19:35.948+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:20:38.691+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:21:41.268+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:22:44.349+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:23:47.203+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:24:50.322+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:25:53.785+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:26:56.833+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:27:59.543+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:29:02.303+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:30:05.78+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:31:09.19+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:32:12.023+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:33:14.856+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:34:17.8+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:35:20.702+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:36:23.312+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:37:26.713+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:38:29.588+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:39:32.359+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:40:35.245+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'daily_new_falcon', 'time': '2023-09-10T13:41:38.088+00:00', 'depth_proc ...
# {'depth_data': [{'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:03:25.501+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:04:28.237+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:08:40.443+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:09:43.585+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:10:46.062+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:11:48.856+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:12:51.324+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:17:03.749+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:19:09.604+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:20:12.834+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:21:15.992+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:25:27.011+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:29:38.842+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:30:42.057+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:33:49.99+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:36:58.449+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:38:00.981+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:39:03.497+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:40:06.527+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:41:09.591+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:43:15.969+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:45:21.835+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:46:24.643+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:50:36.431+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:51:39.825+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T13:52:43.283+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:01:06.037+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:02:08.851+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:04:14.298+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:10:32.334+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:11:35.082+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:16:50.541+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:18:56.718+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:26:17.945+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:27:21.28+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:28:24.261+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:29:26.855+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2023-09-10T14:30:30.151+00:00', 'depth_proc_mm': 0}, {'deployment_id': 'weekly_poetic_g ...
# 6909 results
#                                         deployment_id depth_proc_mm  \
# time
# 2023-09-10 13:00:04.713000+00:00  overly_heroic_squid             0
# 2023-09-10 13:01:08.080000+00:00  overly_heroic_squid             0
# 2023-09-10 13:02:11.297000+00:00  overly_heroic_squid             0
# 2023-09-10 13:03:14.545000+00:00  overly_heroic_squid             0
# 2023-09-10 13:04:17.070000+00:00  overly_heroic_squid             0
#
#                                                   name  depth_inches
# time
# 2023-09-10 13:00:04.713000+00:00  BK - 9th St/Smith St           0.0
# 2023-09-10 13:01:08.080000+00:00  BK - 9th St/Smith St           0.0
# 2023-09-10 13:02:11.297000+00:00  BK - 9th St/Smith St           0.0
# 2023-09-10 13:03:14.545000+00:00  BK - 9th St/Smith St           0.0
# 2023-09-10 13:04:17.070000+00:00  BK - 9th St/Smith St           0.0

# %%
draw_depth_data(df_depth, "September 10-12 2023 around the Gowanus Canal")

# %%
from datetime import datetime, timedelta
# query depth data for all sensors
df_depth = query_depth_data_for_multiple_deployments(
    df_deployments[df_deployments.deployment_id == 'weekly_poetic_guinea'],
    start_time=(datetime.now() - timedelta(days=1)).isoformat(),
    end_time=datetime.now().isoformat(),
)

# show a summary
print(len(df_depth), "results")
df_depth.head()
# Out:
# {'depth_data': [{'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T18:45:50.982+00:00', 'depth_proc_mm': 888}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T19:02:39.39+00:00', 'depth_proc_mm': 891}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T19:05:47.933+00:00', 'depth_proc_mm': 893}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T19:07:53.752+00:00', 'depth_proc_mm': 889}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T19:13:09.811+00:00', 'depth_proc_mm': 892}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T19:16:27.096+00:00', 'depth_proc_mm': 892}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T20:13:07.683+00:00', 'depth_proc_mm': 895}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T20:50:53.041+00:00', 'depth_proc_mm': 897}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T21:23:25.127+00:00', 'depth_proc_mm': 895}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T21:28:39.46+00:00', 'depth_proc_mm': 894}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T22:07:30.13+00:00', 'depth_proc_mm': 897}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-04-30T23:46:12.705+00:00', 'depth_proc_mm': 898}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T00:01:57.169+00:00', 'depth_proc_mm': 898}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T01:30:04.955+00:00', 'depth_proc_mm': 897}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T01:44:46.023+00:00', 'depth_proc_mm': 897}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T02:06:49.237+00:00', 'depth_proc_mm': 898}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T02:08:00.427+00:00', 'depth_proc_mm': 896}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T02:13:14.626+00:00', 'depth_proc_mm': 896}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T02:37:24.535+00:00', 'depth_proc_mm': 898}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T02:45:49.352+00:00', 'depth_proc_mm': 898}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T03:12:05.834+00:00', 'depth_proc_mm': 900}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T03:25:52.103+00:00', 'depth_proc_mm': 897}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T03:33:21.588+00:00', 'depth_proc_mm': 898}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T03:33:29.408+00:00', 'depth_proc_mm': 896}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T03:36:38.335+00:00', 'depth_proc_mm': 899}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T03:41:51.724+00:00', 'depth_proc_mm': 897}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T03:52:21.628+00:00', 'depth_proc_mm': 896}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T04:00:45.085+00:00', 'depth_proc_mm': 899}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T04:02:51.826+00:00', 'depth_proc_mm': 899}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T04:03:54.424+00:00', 'depth_proc_mm': 899}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T04:06:00.372+00:00', 'depth_proc_mm': 899}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T04:11:14.813+00:00', 'depth_proc_mm': 896}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T04:13:20.842+00:00', 'depth_proc_mm': 898}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T04:15:26.642+00:00', 'depth_proc_mm': 899}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T04:17:32.281+00:00', 'depth_proc_mm': 900}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T04:22:48.531+00:00', 'depth_proc_mm': 899}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T04:23:51.825+00:00', 'depth_proc_mm': 899}, {'deployment_id': 'weekly_poetic_guinea', 'time': '2024-05-01T04: ...
# 217 results
#                                          deployment_id  depth_proc_mm  \
# time
# 2024-04-30 18:45:50.982000+00:00  weekly_poetic_guinea            888
# 2024-04-30 19:02:39.390000+00:00  weekly_poetic_guinea            891
# 2024-04-30 19:05:47.933000+00:00  weekly_poetic_guinea            893
# 2024-04-30 19:07:53.752000+00:00  weekly_poetic_guinea            889
# 2024-04-30 19:13:09.811000+00:00  weekly_poetic_guinea            892
#
#                                                     name  depth_inches
# time
# 2024-04-30 18:45:50.982000+00:00  BK - Carroll St/4th Av      34.96063
# 2024-04-30 19:02:39.390000+00:00  BK - Carroll St/4th Av      35.07874
# 2024-04-30 19:05:47.933000+00:00  BK - Carroll St/4th Av      35.15748
# 2024-04-30 19:07:53.752000+00:00  BK - Carroll St/4th Av      35.00000
# 2024-04-30 19:13:09.811000+00:00  BK - Carroll St/4th Av      35.11811

# %% [markdown]
# ## Coming early 2024: querying specific events
#
#  - Query storm events (e.g. Hurricane Henri, certain dates, etc.)
#  - Query data between event start/stop times
